# %% [markdown]
# <a href="https://colab.research.google.com/github/VishwanathGurijala/CS-6647-XTIA-23-T5/blob/main/homework3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## The Uniform Distribution

# %% [markdown]
# Load libraries. We use the scipy.stats library.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import uniform, norm, binom

# %% [markdown]
# Use scipy library to create a randam uniform distribution data (100000 numbers from 0 to 10)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import uniform

# Create a random uniform distribution with 100,000 numbers from 0 to 10
data_uniform = uniform.rvs(size=100000, loc=0, scale=10)

# Plot the histogram of the random uniform distribution
plt.hist(data_uniform, bins=100, density=True)
plt.xlabel('Value')
plt.ylabel('Density')
plt.title('Uniform Distribution')
plt.show()

# %% [markdown]
# Plot the following density distribution.
# You can use figsize=(9,9), xlim=(-1,11)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import uniform

# Create a random uniform distribution with 100,000 numbers from 0 to 10
data_uniform = uniform.rvs(size=100000, loc=0, scale=10)

# Plot the density distribution
plt.figure(figsize=(9, 9))
plt.hist(data_uniform, bins=100, density=True)
plt.xlim(-1, 11)
plt.xlabel('Value')
plt.ylabel('Density')
plt.title('Uniform Distribution')
plt.show()

# %% [markdown]
# Check scipy libraries and use useful functions.

# %% [markdown]
# cdf (cumulative distribution function) gives you the area under the distribution's density curve to the left of a certain value on the x axis. Calculate cdf with x axis from 0 to 2.5.

# %%
from scipy.stats import uniform

# Define the parameters for the uniform distribution
loc = 0
scale = 10

# Calculate the CDF for the range from 0 to 2.5
x_values = [0, 2.5]
cdf_values = uniform.cdf(x_values, loc=loc, scale=scale)

print(cdf_values)
# Out:
# [0.   0.25]

# %% [markdown]
# ppf() is the inverse of cdf(): it returns the x axis cutoff value (quantile) associated with a given probability. Caculate the cutoff value for propabality with 40%.

# %%
from scipy.stats import uniform

# Define the parameters for the uniform distribution
loc = 0
scale = 10

# Calculate the cutoff value for a probability of 0.4
probability = 0.4
cutoff_value = uniform.ppf(probability, loc=loc, scale=scale)

print(cutoff_value)
# Out:
# 4.0

# %% [markdown]
# Demonstrate for uniform distribution, x values within the range will have the same probability desity.  x values outside the range have a probability density of 0. The output is similar as the following.

# %%
from scipy.stats import uniform

# Define the parameters for the uniform distribution
loc = 0
scale = 10

# Calculate the probability density for different x values
x_values = [-1, 2, 5, 8, 11]

for x in x_values:
    density = uniform.pdf(x, loc=loc, scale=scale)
    print(f"Density at x value {x}: {density}")
# Out:
# Density at x value -1: 0.0
# Density at x value 2: 0.1
# Density at x value 5: 0.1
# Density at x value 8: 0.1
# Density at x value 11: 0.0

# %% [markdown]
# Probability distribution functions in scipy also support median(), mean(), var() and std().

# %% [markdown]
# ## The Normal Distribution

# %% [markdown]
# Use scipy's norm to have normal distribution (see the graph below) .  The normal distribution has default vaues of  mean of 0 and standard deviation of 1. Investigate what percentage of data generated by a default normal distribution is below -1. What percentage of data generated is above 1 and what percentage lies between -1 and 1. Print the three percentages. The output is similar as the following.

# %%
from scipy.stats import norm

# Define the parameters for the normal distribution
mean = 0
std_dev = 1

# Calculate the percentages using CDF
percentage_below_minus1 = norm.cdf(-1, loc=mean, scale=std_dev) * 100
percentage_above_1 = (1 - norm.cdf(1, loc=mean, scale=std_dev)) * 100
percentage_between_minus1_and_1 = (norm.cdf(1, loc=mean, scale=std_dev) - norm.cdf(-1, loc=mean, scale=std_dev)) * 100

# Print the percentages
print("Percentage below -1:", percentage_below_minus1)
print("Percentage above 1:", percentage_above_1)
print("Percentage between -1 and 1:", percentage_between_minus1_and_1)
# Out:
# Percentage below -1: 15.865525393145708
# Percentage above 1: 15.865525393145708
# Percentage between -1 and 1: 68.26894921370858

# %% [markdown]
# Plotting is not required. The codes will be included in the solution. The image below shows the bell shape normal distribution.

# %% [markdown]
# print the ppf for 2.5% cutoff and 97.5% cutoff. The output is similar as the following

# %%
from scipy.stats import norm

# Define the parameters for the normal distribution
mean = 0
std_dev = 1

# Calculate the ppf values
cutoff_2_5 = norm.ppf(0.025, loc=mean, scale=std_dev)
cutoff_97_5 = norm.ppf(0.975, loc=mean, scale=std_dev)

# Print the ppf values
print("2.5% cutoff:", cutoff_2_5)
print("97.5% cutoff:", cutoff_97_5)
# Out:
# 2.5% cutoff: -1.9599639845400545
# 97.5% cutoff: 1.959963984540054

# %% [markdown]
# The quantile output above confirms that roughly 5% of the data lies more than 2 standard deviations from the mean.

# %% [markdown]
# ## The Binomial Distribution

# %% [markdown]
# We will use binomial distribution to model coin flips. The scipy name for the binomial is binom. Here we set the number of flips per trial to 10,  the number of trials to 10000, and success probability to 0.5.
#
# Create a random binomial distribution data "fair_coin_flips" in the code line below.

# %%
from scipy.stats import binom

# Define the parameters for the binomial distribution
num_flips_per_trial = 10
num_trials = 10000
success_probability = 0.5

# Generate random binomial distribution data
fair_coin_flips = binom.rvs(n=num_flips_per_trial, p=success_probability, size=num_trials)

# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import binom

# Define the parameters for the binomial distribution
num_flips_per_trial = 10
num_trials = 10000
success_probability = 0.5

# Generate random binomial distribution data
fair_coin_flips = binom.rvs(n=num_flips_per_trial, p=success_probability, size=num_trials)

# Print out the counts for each number of heads
counts = pd.Series(fair_coin_flips).value_counts().sort_index()
print("Counts of each number of heads:")
print(counts)

# Draw the histogram
plt.hist(fair_coin_flips, range=(-0.5, 10.5), bins=11)
plt.xlabel("Number of Heads")
plt.ylabel("Frequency")
plt.title("Histogram of Coin Flips")
plt.show()
# Out:
# Counts of each number of heads:
# 0       10
# 1      123
# 2      441
# 3     1167
# 4     1983
# 5     2449
# 6     2087
# 7     1196
# 8      457
# 9       84
# 10       3
# dtype: int64

# %% [markdown]
# The histogram above shows us that a binomial distribution with a 50% probability of success is roughly symmetric, with the most likely outcomes lying at the center.
# Change the success rate to 0.8, implement the codes similar as above to show the distribution won't be symmetric:

# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import binom

# Define the parameters for the binomial distribution
num_flips_per_trial = 10
num_trials = 10000
success_probability = 0.8

# Generate random binomial distribution data
fair_coin_flips = binom.rvs(n=num_flips_per_trial, p=success_probability, size=num_trials)

# Print out the counts for each number of heads
counts = pd.Series(fair_coin_flips).value_counts().sort_index()
print("Counts of each number of heads:")
print(counts)

# Draw the histogram
plt.hist(fair_coin_flips, range=(-0.5, 10.5), bins=11)
plt.xlabel("Number of Heads")
plt.ylabel("Frequency")
plt.title("Histogram of Coin Flips")
plt.show()
# Out:
# Counts of each number of heads:
# 2        1
# 3        8
# 4       48
# 5      272
# 6      884
# 7     1971
# 8     2986
# 9     2777
# 10    1053
# dtype: int64

# %% [markdown]
# Continue from above binomial distribution(success rate=0.8), give the codes to get the probability of achieving 5 heads or less with 10 flips.

# %%
from scipy.stats import binom

# Define the parameters for the binomial distribution
num_flips_per_trial = 10
success_probability = 0.8

# Calculate the probability of achieving 5 heads or less
probability_5_heads_or_less = binom.cdf(5, n=num_flips_per_trial, p=success_probability)

print("Probability of achieving 5 heads or less with 10 flips:", probability_5_heads_or_less)
# Out:
# Probability of achieving 5 heads or less with 10 flips: 0.03279349759999997

# %% [markdown]
# Continue from above binomial distribution(success rate=0.8), give the codes to get the probability of achieving 9 heads or more with 10 flips.

# %%
from scipy.stats import binom

# Define the parameters for the binomial distribution
num_flips_per_trial = 10
success_probability = 0.8

# Calculate the probability of achieving 9 heads or more
probability_9_heads_or_more = 1 - binom.cdf(8, n=num_flips_per_trial, p=success_probability)

print("Probability of achieving 9 heads or more with 10 flips:", probability_9_heads_or_more)
# Out:
# Probability of achieving 9 heads or more with 10 flips: 0.37580963840000015

# %% [markdown]
# For continuous probability density functions, you use pdf() to check the probability density at a given x value. For discrete distributions like the binomial, use stats.distribution.pmf() (probability mass function) to check the mass (proportion of observations) at given number of successes k.
# Write codes to give the probability density at 5 heads with success rate of 0.5 of 10 flips.

# %%
from scipy.stats import binom

# Define the parameters for the binomial distribution
num_flips_per_trial = 10
success_probability = 0.5

# Calculate the probability density at 5 heads
probability_density_5_heads = binom.pmf(5, n=num_flips_per_trial, p=success_probability)

print("Probability density at 5 heads with 10 flips:", probability_density_5_heads)
# Out:
# Probability density at 5 heads with 10 flips: 0.24609375000000003

# %% [markdown]
# What about the probability density at 8 heads with success rate of 0.8 of 10 flips?

# %%
from scipy.stats import binom

# Define the parameters for the binomial distribution
num_flips_per_trial = 10
success_probability = 0.8

# Calculate the probability density at 8 heads
probability_density_8_heads = binom.pmf(8, n=num_flips_per_trial, p=success_probability)

print("Probability density at 8 heads with 10 flips:", probability_density_8_heads)
# Out:
# Probability density at 8 heads with 10 flips: 0.30198988799999993

# %% [markdown]
# ## Wrap Up

# %% [markdown]
# Extra information of Exponential Distributions and Poisson Distributions will be given in the solution.
#
#
# Python's scipy library contains functions that make it easy to work with a wide range of probability distributions, including [many that we did not discuss](https://docs.scipy.org/doc/scipy/reference/stats.html) in this lesson. Probability distribution functions are useful for generating random data, modeling random events and aiding with statistical tests and analysis.
